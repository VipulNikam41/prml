# %%
import pandas as pd
from scipy import sparse

# %%
ratings = pd.read_csv('https://raw.githubusercontent.com/codeheroku/Introduction-to-Machine-Learning/master/Collaborative%20Filtering/dataset/ratings.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/codeheroku/Introduction-to-Machine-Learning/master/Collaborative%20Filtering/dataset/movies.csv')
ratings = pd.merge(movies,ratings).drop(['genres','timestamp'],axis=1)
print(ratings.shape)
ratings.head()
# Out:
# (100836, 4)
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       1     4.0
# 1        1  Toy Story (1995)       5     4.0
# 2        1  Toy Story (1995)       7     4.5
# 3        1  Toy Story (1995)      15     2.5
# 4        1  Toy Story (1995)      17     4.5

# %%
userRatings = ratings.pivot_table(index=['userId'],columns=['title'],values='rating')
userRatings.head()
# Out:
# title   '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# userId              ...
# 1              NaN  ...                                        NaN
# 2              NaN  ...                                        NaN
# 3              NaN  ...                                        NaN
# 4              NaN  ...                                        NaN
# 5              NaN  ...                                        NaN
#
# [5 rows x 9719 columns]

# %%
#print("Before: ",userRatings.shape)
userRatings = userRatings.dropna(thresh=1, axis=1).fillna(0,axis=1)
#userRatings.fillna(0, inplace=True)
#print("After: ",userRatings.shape)

# %%
corrMatrix = userRatings.corr(method='pearson')
corrMatrix.head(200)
# Out:
# title                                    '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# title                                                ...
# '71 (2014)                                 1.000000  ...                                  -0.001642
# 'Hellboy': The Seeds of Creation (2004)   -0.001642  ...                                  -0.001642
# 'Round Midnight (1986)                    -0.002324  ...                                  -0.002324
# 'Salem's Lot (2004)                       -0.001642  ...                                  -0.001642
# 'Til There Was You (1997)                 -0.002254  ...                                  -0.002254
# ...                                             ...  ...                                        ...
# Above the Rim (1994)                      -0.001642  ...                                  -0.001642
# Abraham Lincoln: Vampire Hunter (2012)     0.363717  ...                                  -0.003978
# ...

# %%
def get_similar(movie_name,rating):
    similar_ratings = corrMatrix[movie_name]*(rating-2.5)
    similar_ratings = similar_ratings.sort_values(ascending=False)
    #print(type(similar_ratings))
    return similar_ratings

# %%
romantic_lover = [("(500) Days of Summer (2009)",5),("Alice in Wonderland (2010)",3),("Aliens (1986)",1),("2001: A Space Odyssey (1968)",2)]
similar_movies = pd.DataFrame()
for movie,rating in romantic_lover:
    similar_movies = similar_movies.append(get_similar(movie,rating),ignore_index = True)

similar_movies.head(10)
# Out:
#    '71 (2014)  ...  À nous la liberté (Freedom for Us) (1931)
# 0    0.339857  ...                                  -0.026420
# 1   -0.004171  ...                                  -0.004171
# 2   -0.152293  ...                                   0.029826
# 3   -0.049327  ...                                   0.009024
#
# [4 rows x 9719 columns]

# %%
similar_movies.sum().sort_values(ascending=False).head(20)
# Out:
# (500) Days of Summer (2009)                      2.584556
# Alice in Wonderland (2010)                       1.395229
# Silver Linings Playbook (2012)                   1.254800
# Yes Man (2008)                                   1.116264
# Adventureland (2009)                             1.112235
# Marley & Me (2008)                               1.108381
# About Time (2013)                                1.102192
# Crazy, Stupid, Love. (2011)                      1.088757
# 50/50 (2011)                                     1.086517
# Help, The (2011)                                 1.075963
# Up in the Air (2009)                             1.053037
# Holiday, The (2006)                              1.034470
# Friends with Benefits (2011)                     1.030875
# Notebook, The (2004)                             1.025880
# Easy A (2010)                                    1.015771
# Secret Life of Walter Mitty, The (2013)          0.997979
# ...

# %%
action_lover = [("Amazing Spider-Man, The (2012)",5),("Mission: Impossible III (2006)",4),("Toy Story 3 (2010)",2),("2 Fast 2 Furious (Fast and the Furious 2, The) (2003)",4)]
similar_movies = pd.DataFrame()
for movie,rating in action_lover:
    similar_movies = similar_movies.append(get_similar(movie,rating),ignore_index = True)

similar_movies.head(10)
similar_movies.sum().sort_values(ascending=False).head(20)
# Out:
# Amazing Spider-Man, The (2012)                           3.233134
# Mission: Impossible III (2006)                           2.874798
# 2 Fast 2 Furious (Fast and the Furious 2, The) (2003)    2.701477
# Total Recall (2012)                                      2.377751
# Hansel & Gretel: Witch Hunters (2013)                    2.242785
# Over the Hedge (2006)                                    2.229721
# Riddick (2013)                                           2.205002
# Crank (2006)                                             2.176259
# Mission: Impossible - Ghost Protocol (2011)              2.159666
# Hancock (2008)                                           2.156098
# The Amazing Spider-Man 2 (2014)                          2.153677
# Hellboy (2004)                                           2.137518
# Snakes on a Plane (2006)                                 2.137396
# Cowboys & Aliens (2011)                                  2.137133
# ...

# %%
drama_lover = [("Three Colors: Red (Trois couleurs: Rouge) (1994)",5),("Deep End, The (2001)",4),("L.I.E. (2001)",2),("Manderlay (2005)",4)]
similar_movies = pd.DataFrame()
for movie,rating in drama_lover:
    similar_movies = similar_movies.append(get_similar(movie,rating),ignore_index = True)

similar_movies.head(10)
similar_movies.sum().sort_values(ascending=False).head(20)
# Out:
# Three Colors: Red (Trois couleurs: Rouge) (1994)    3.225604
# Bread and Tulips (Pane e tulipani) (2000)           2.893842
# Impostors, The (1998)                               2.748746
# Deep End, The (2001)                                2.698531
# Marnie (1964)                                       2.679640
# Hamlet (1948)                                       2.673959
# Imitation of Life (1959)                            2.510328
# Grass Is Greener, The (1960)                        2.493457
# Send Me No Flowers (1964)                           2.493457
# Washington Square (1997)                            2.489850
# Manderlay (2005)                                    2.464674
# Pat and Mike (1952)                                 2.459956
# I Confess (1953)                                    2.459956
# 11'09"01 - September 11 (2002)                      2.459956
# Woman of the Year (1942)                            2.459956
# ...

# %%
adventure_lover = [("Phineas and Ferb the Movie: Across the 2nd Dimension (2011)",4),("Conan the Barbarian (2011)",3),("Captain America: The First Avenger (2011)",5),("X-Men: First Class (2011)",4),("Season of the Witch (2011)",2)]
similar_movies = pd.DataFrame()
for movie,rating in adventure_lover:
    similar_movies = similar_movies.append(get_similar(movie,rating),ignore_index = True)

similar_movies.head(10)
similar_movies.sum().sort_values(ascending=False).head(20)
# Out:
# Captain America: The First Avenger (2011)       3.654611
# X-Men: First Class (2011)                       3.016920
# X-Men: Days of Future Past (2014)               2.773676
# Thor (2011)                                     2.720224
# Iron Man 3 (2013)                               2.649124
# Avengers, The (2012)                            2.500058
# Avengers: Age of Ultron (2015)                  2.473386
# Iron Man 2 (2010)                               2.372598
# Star Trek Into Darkness (2013)                  2.314000
# Thor: The Dark World (2013)                     2.268137
# Guardians of the Galaxy (2014)                  2.242153
# World's End, The (2013)                         2.241319
# Muppets, The (2011)                             2.164435
# Iron Man (2008)                                 2.151364
# Sherlock Holmes (2009)                          2.116296
# Kick-Ass (2010)                                 2.105998
# ...

# %%
https://raw.githubusercontent.com/codeheroku/Introduction-to-Machine-Learning/master/Collaborative%20Filtering/dataset/movies.csv
## LINK TO THE MOVIE DATASET
